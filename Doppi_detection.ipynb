# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.0/705.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="o4Vv93v2E5r3NdcoZUGG")
project = rf.workspace("labelingdoppi").project("detecting-doppi")
dataset = project.version(3).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/Detecting-Doppi-3/data.yaml epochs=50
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 161MB/s]
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/doppi_rasm.jpg
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/doppi_rasm.jpg: 640x480 1 uzbek_doppisi, 108.4ms
# Speed: 2.3ms preprocess, 108.4ms inference, 575.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/doppi_video.mp4
# Out:
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 111.7ms
# video 1/1 (2/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.8ms
# video 1/1 (3/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (4/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (5/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.6ms
# video 1/1 (6/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (7/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (8/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (9/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# video 1/1 (10/335) /content/doppi_video.mp4: 640x384 1 uzbek_doppisi, 10.7ms
# ...
